# %% [markdown]
# # Import the essential libraries

# %%
# Essential and common packages
import os
import glob

# Plots and bars
import matplotlib.pyplot as plt

# Computation library
import numpy as np

# Tensorflow for building the resnet50 model
import tensorflow.python.keras as k
import tensorflow as tf
from tensorflow.keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from tensorflow.keras.initializers import random_uniform, glorot_uniform
from tensorflow.keras.models import Model

# Sklearn for confusion matrix
import itertools
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay

# For visualization of plots without plt.show()
# %matplotlib inline

# %%
tf.__version__
# Out:
# '2.10.1'

# %% [markdown]
# # Define the required variable

# %%
dataset_url = r'C:\Users\awlad\Desktop\Deep Learning Course\Short Course\Code Materials\New folder\CNN Image Classification\Data'
batch_size = 32
img_height = 64
img_width = 64
validation_split=0.2
rescale=1.0/255

# %% [markdown]
# # Data preparation for the model

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(validation_split=validation_split, rescale=rescale)
dataset = tf.keras.preprocessing.image_dataset_from_directory(dataset_url, image_size=(img_height, img_width), batch_size=batch_size)
# Out:
# Found 27000 files belonging to 10 classes.

# %%
train_dataset = datagen.flow_from_directory(batch_size=batch_size,
                                           directory=dataset_url,
                                           shuffle=True,
                                           target_size=(img_height, img_width),
                                           subset="training",
                                           class_mode='categorical')
# Out:
# Found 21600 images belonging to 10 classes.

# %%
test_dataset = datagen.flow_from_directory(batch_size=batch_size,
                                           directory=dataset_url,
                                           shuffle=True,
                                           target_size=(img_height, img_width),
                                           subset="validation",
                                           class_mode='categorical')
# Out:
# Found 5400 images belonging to 10 classes.

# %% [markdown]
# # Visualization of input datasets

# %%
class_names = dataset.class_names
plt.figure(figsize=(10, 10))
for images, labels in dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# # ResNet50 Model building
#
# ##### ResNet50 Architecture
# ![resnet50](https://raw.githubusercontent.com/iamtekson/deep-learning-for-earth-observation/main/Notebooks/01.%20image-classification/img/resnet50.png)
#
# ###### ResNet Identity block
# ![identity block](https://raw.githubusercontent.com/iamtekson/deep-learning-for-earth-observation/main/Notebooks/01.%20image-classification/img/convblock.png)
#
# ###### ResNet Convolution Block
# ![conv block](https://raw.githubusercontent.com/iamtekson/deep-learning-for-earth-observation/main/Notebooks/01.%20image-classification/img/convblock.png)

# %%
def identity_block(X, f, filters, training=True, initializer=random_uniform):
    """
    Implementation of the identity block
    
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    training -- True: Behave in training mode
                False: Behave in inference mode
    initializer -- to set up the initial weights of a layer. Equals to random uniform initializer
    
    Returns:
    X -- output of the identity block, tensor of shape (n_H, n_W, n_C)
    """
    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value.
    X_shortcut = X
    cache = []
    # First component of main path
    X = Conv2D(filters = F1, kernel_size = 1, strides = (1, 1), padding = 'valid', kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training = training) # Default axis
    X = Activation('relu')(X)
    
    # Second component of main path (≈3 lines)
    X = Conv2D(filters = F2, kernel_size = (f, f), strides = (1, 1), padding = 'same', kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training = training)
    X = Activation('relu')(X)

    # Third component of main path (≈2 lines)
    X = Conv2D(filters = F3, kernel_size = (1, 1), strides = (1, 1), padding = 'valid', kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training = training)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation (≈2 lines)
    X = Add()([X_shortcut, X])
    X = X = Activation('relu')(X, training = training)

    return X

# %%
def convolutional_block(X, f, filters, s = 2, training=True, initializer=glorot_uniform):
    """
    Implementation of the convolutional block
    
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    s -- Integer, specifying the stride to be used
    training -- True: Behave in training mode
                False: Behave in inference mode
    initializer -- to set up the initial weights of a layer. Equals to Glorot uniform initializer, 
                   also called Xavier uniform initializer.
    
    Returns:
    X -- output of the convolutional block, tensor of shape (n_H, n_W, n_C)
    """
    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value
    X_shortcut = X


    ##### MAIN PATH #####
    
    # First component of main path glorot_uniform(seed=0)
    X = Conv2D(filters = F1, kernel_size = 1, strides = (s, s), padding='valid', kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training=training)
    X = Activation('relu')(X)

    
    # Second component of main path (≈3 lines)
    X = Conv2D(F2, (f, f), strides = (1, 1), padding = 'same', kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training = training)
    X = Activation('relu')(X)

    # Third component of main path (≈2 lines)
    X = Conv2D(F3, (1, 1), strides = (1, 1), padding = 'valid', kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training = training)

    ##### SHORTCUT PATH #### (≈2 lines)
    X_shortcut = Conv2D(F3, (1, 1), strides = (s, s), padding = 'valid', kernel_initializer = initializer(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis = 3)(X_shortcut, training = training)

    # Final step: Add shortcut value to main path (Use this order [X, X_shortcut]), and pass it through a RELU activation
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
    
    return X

# %%
def ResNet50(input_shape = (64, 64, 3), classes = 6):
    """
    Stage-wise implementation of the architecture of the popular ResNet50:
    CONV2D -> BATCHNORM -> RELU -> MAXPOOL -> CONVBLOCK -> IDBLOCK*2 -> CONVBLOCK -> IDBLOCK*3
    -> CONVBLOCK -> IDBLOCK*5 -> CONVBLOCK -> IDBLOCK*2 -> AVGPOOL -> FLATTEN -> DENSE 

    Arguments:
    input_shape -- shape of the images of the dataset
    classes -- integer, number of classes

    Returns:
    model -- a Model() instance in Keras
    """
    
    # Define the input as a tensor with shape input_shape
    X_input = Input(input_shape)

    
    # Zero-Padding
    X = ZeroPadding2D((3, 3))(X_input)
    
    # Stage 1
    X = Conv2D(64, (7, 7), strides = (2, 2), kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3)(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    # Stage 2
    X = convolutional_block(X, f = 3, filters = [64, 64, 256], s = 1)
    X = identity_block(X, 3, [64, 64, 256])
    X = identity_block(X, 3, [64, 64, 256])
    
   # Stage 3 (≈4 lines)
    X = convolutional_block(X, f = 3, filters = [128, 128, 512], s = 2)
    X = identity_block(X, 3, [128, 128, 512])
    X = identity_block(X, 3, [128, 128, 512])
    X = identity_block(X, 3, [128, 128, 512])

    # Stage 4 (≈6 lines)
    X = convolutional_block(X, f = 3, filters = [256, 256, 1024], s = 2)
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])

    # Stage 5 (≈3 lines)
    X = convolutional_block(X, f = 3, filters = [512, 512, 2048], s = 2)
    X = identity_block(X, 3, [512, 512, 2048])
    X = identity_block(X, 3, [512, 512, 2048])

    # AVGPOOL (≈1 line). Use "X = AveragePooling2D(...)(X)"
    X = AveragePooling2D(pool_size = (2, 2), name = 'avg_pool')(X)
    

    # output layer
    X = Flatten()(X)
    X = Dense(classes, activation='softmax', kernel_initializer = glorot_uniform(seed=0))(X)
    
    
    # Create model
    model = Model(inputs = X_input, outputs = X)

    return model

# %% [markdown]
# # Model train

# %%
model = ResNet50(input_shape=(64,64,3), classes=10)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  zero_padding2d_2 (ZeroPadding2  (None, 70, 70, 3)   0           ['input_3[0][0]']
#  D)
#
#  conv2d_106 (Conv2D)            (None, 32, 32, 64)   9472        ['zero_padding2d_2[0][0]']
#
#  batch_normalization_106 (Batch  (None, 32, 32, 64)  256         ['conv2d_106[0][0]']
#  Normalization)
#
#  activation_98 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_106[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 15, 15, 64)  0           ['activation_98[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 15, 15, 64)   4160        ['max_pooling2d_2[0][0]']
#
#  batch_normalization_107 (Batch  (None, 15, 15, 64)  256         ['conv2d_107[0][0]']
#  Normalization)
#
#  activation_99 (Activation)     (None, 15, 15, 64)   0           ['batch_normalization_107[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 15, 15, 64)   36928       ['activation_99[0][0]']
#
#  batch_normalization_108 (Batch  (None, 15, 15, 64)  256         ['conv2d_108[0][0]']
#  Normalization)
#
#  activation_100 (Activation)    (None, 15, 15, 64)   0           ['batch_normalization_108[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 15, 15, 256)  16640       ['activation_100[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 15, 15, 256)  16640       ['max_pooling2d_2[0][0]']
#
#  batch_normalization_109 (Batch  (None, 15, 15, 256)  1024       ['conv2d_109[0][0]']
#  Normalization)
#
#  batch_normalization_110 (Batch  (None, 15, 15, 256)  1024       ['conv2d_110[0][0]']
#  Normalization)
#
#  add_32 (Add)                   (None, 15, 15, 256)  0           ['batch_normalization_109[0][0]',
#                                                                   'batch_normalization_110[0][0]']
#
#  activation_101 (Activation)    (None, 15, 15, 256)  0           ['add_32[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 15, 15, 64)   16448       ['activation_101[0][0]']
#
#  batch_normalization_111 (Batch  (None, 15, 15, 64)  256         ['conv2d_111[0][0]']
#  Normalization)
#
#  activation_102 (Activation)    (None, 15, 15, 64)   0           ['batch_normalization_111[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 15, 15, 64)   36928       ['activation_102[0][0]']
#
#  batch_normalization_112 (Batch  (None, 15, 15, 64)  256         ['conv2d_112[0][0]']
#  Normalization)
#
#  activation_103 (Activation)    (None, 15, 15, 64)   0           ['batch_normalization_112[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 15, 15, 256)  16640       ['activation_103[0][0]']
#
#  batch_normalization_113 (Batch  (None, 15, 15, 256)  1024       ['conv2d_113[0][0]']
#  Normalization)
#
#  add_33 (Add)                   (None, 15, 15, 256)  0           ['activation_101[0][0]',
#                                                                   'batch_normalization_113[0][0]']
#
#  activation_104 (Activation)    (None, 15, 15, 256)  0           ['add_33[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 15, 15, 64)   16448       ['activation_104[0][0]']
#
#  batch_normalization_114 (Batch  (None, 15, 15, 64)  256         ['conv2d_114[0][0]']
#  Normalization)
#
#  activation_105 (Activation)    (None, 15, 15, 64)   0           ['batch_normalization_114[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 15, 15, 64)   36928       ['activation_105[0][0]']
#
#  batch_normalization_115 (Batch  (None, 15, 15, 64)  256         ['conv2d_115[0][0]']
#  Normalization)
#
#  activation_106 (Activation)    (None, 15, 15, 64)   0           ['batch_normalization_115[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 15, 15, 256)  16640       ['activation_106[0][0]']
#
#  batch_normalization_116 (Batch  (None, 15, 15, 256)  1024       ['conv2d_116[0][0]']
#  Normalization)
#
#  add_34 (Add)                   (None, 15, 15, 256)  0           ['activation_104[0][0]',
#                                                                   'batch_normalization_116[0][0]']
#
#  activation_107 (Activation)    (None, 15, 15, 256)  0           ['add_34[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 8, 8, 128)    32896       ['activation_107[0][0]']
#
#  batch_normalization_117 (Batch  (None, 8, 8, 128)   512         ['conv2d_117[0][0]']
#  Normalization)
#
#  activation_108 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_117[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 8, 8, 128)    147584      ['activation_108[0][0]']
#
#  batch_normalization_118 (Batch  (None, 8, 8, 128)   512         ['conv2d_118[0][0]']
#  Normalization)
#
#  activation_109 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_118[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 8, 8, 512)    66048       ['activation_109[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 8, 8, 512)    131584      ['activation_107[0][0]']
#
#  batch_normalization_119 (Batch  (None, 8, 8, 512)   2048        ['conv2d_119[0][0]']
#  Normalization)
#
#  batch_normalization_120 (Batch  (None, 8, 8, 512)   2048        ['conv2d_120[0][0]']
#  Normalization)
#
#  add_35 (Add)                   (None, 8, 8, 512)    0           ['batch_normalization_119[0][0]',
#                                                                   'batch_normalization_120[0][0]']
#
#  activation_110 (Activation)    (None, 8, 8, 512)    0           ['add_35[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 8, 8, 128)    65664       ['activation_110[0][0]']
#
#  batch_normalization_121 (Batch  (None, 8, 8, 128)   512         ['conv2d_121[0][0]']
#  Normalization)
#
#  activation_111 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_121[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 8, 8, 128)    147584      ['activation_111[0][0]']
#
#  batch_normalization_122 (Batch  (None, 8, 8, 128)   512         ['conv2d_122[0][0]']
#  Normalization)
#
#  activation_112 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_122[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 8, 8, 512)    66048       ['activation_112[0][0]']
#
#  batch_normalization_123 (Batch  (None, 8, 8, 512)   2048        ['conv2d_123[0][0]']
#  Normalization)
#
#  add_36 (Add)                   (None, 8, 8, 512)    0           ['activation_110[0][0]',
#                                                                   'batch_normalization_123[0][0]']
#
#  activation_113 (Activation)    (None, 8, 8, 512)    0           ['add_36[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 8, 8, 128)    65664       ['activation_113[0][0]']
#
#  batch_normalization_124 (Batch  (None, 8, 8, 128)   512         ['conv2d_124[0][0]']
#  Normalization)
#
#  activation_114 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_124[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 8, 8, 128)    147584      ['activation_114[0][0]']
#
#  batch_normalization_125 (Batch  (None, 8, 8, 128)   512         ['conv2d_125[0][0]']
#  Normalization)
#
#  activation_115 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_125[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 8, 8, 512)    66048       ['activation_115[0][0]']
#
#  batch_normalization_126 (Batch  (None, 8, 8, 512)   2048        ['conv2d_126[0][0]']
#  Normalization)
#  add_37 (Add)                   (None, 8, 8, 512)    0           ['activation_113[0][0]',
#                                                                   'batch_normalization_126[0][0]']
#
#  activation_116 (Activation)    (None, 8, 8, 512)    0           ['add_37[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 8, 8, 128)    65664       ['activation_116[0][0]']
#
#  batch_normalization_127 (Batch  (None, 8, 8, 128)   512         ['conv2d_127[0][0]']
#  Normalization)
#
#  activation_117 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_127[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 8, 8, 128)    147584      ['activation_117[0][0]']
#
#  batch_normalization_128 (Batch  (None, 8, 8, 128)   512         ['conv2d_128[0][0]']
#  Normalization)
#
#  activation_118 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_128[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 8, 8, 512)    66048       ['activation_118[0][0]']
#
#  batch_normalization_129 (Batch  (None, 8, 8, 512)   2048        ['conv2d_129[0][0]']
#  Normalization)
#
#  add_38 (Add)                   (None, 8, 8, 512)    0           ['activation_116[0][0]',
#                                                                   'batch_normalization_129[0][0]']
#
#  activation_119 (Activation)    (None, 8, 8, 512)    0           ['add_38[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 4, 4, 256)    131328      ['activation_119[0][0]']
#
#  batch_normalization_130 (Batch  (None, 4, 4, 256)   1024        ['conv2d_130[0][0]']
#  Normalization)
#
#  activation_120 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_130[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 4, 4, 256)    590080      ['activation_120[0][0]']
#
#  batch_normalization_131 (Batch  (None, 4, 4, 256)   1024        ['conv2d_131[0][0]']
#  Normalization)
#
#  activation_121 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_131[0][0]']
#
#  conv2d_132 (Conv2D)            (None, 4, 4, 1024)   263168      ['activation_121[0][0]']
#
#  conv2d_133 (Conv2D)            (None, 4, 4, 1024)   525312      ['activation_119[0][0]']
#
#  batch_normalization_132 (Batch  (None, 4, 4, 1024)  4096        ['conv2d_132[0][0]']
#  Normalization)
#
#  batch_normalization_133 (Batch  (None, 4, 4, 1024)  4096        ['conv2d_133[0][0]']
#  Normalization)
#
#  add_39 (Add)                   (None, 4, 4, 1024)   0           ['batch_normalization_132[0][0]',
#                                                                   'batch_normalization_133[0][0]']
#
#  activation_122 (Activation)    (None, 4, 4, 1024)   0           ['add_39[0][0]']
#
#  conv2d_134 (Conv2D)            (None, 4, 4, 256)    262400      ['activation_122[0][0]']
#
#  batch_normalization_134 (Batch  (None, 4, 4, 256)   1024        ['conv2d_134[0][0]']
#  Normalization)
#
#  activation_123 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_134[0][0]']
#
#  conv2d_135 (Conv2D)            (None, 4, 4, 256)    590080      ['activation_123[0][0]']
#
#  batch_normalization_135 (Batch  (None, 4, 4, 256)   1024        ['conv2d_135[0][0]']
#  Normalization)
#
#  activation_124 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_135[0][0]']
#
#  conv2d_136 (Conv2D)            (None, 4, 4, 1024)   263168      ['activation_124[0][0]']
#
#  batch_normalization_136 (Batch  (None, 4, 4, 1024)  4096        ['conv2d_136[0][0]']
#  Normalization)
#
#  add_40 (Add)                   (None, 4, 4, 1024)   0           ['activation_122[0][0]',
#                                                                   'batch_normalization_136[0][0]']
#
#  activation_125 (Activation)    (None, 4, 4, 1024)   0           ['add_40[0][0]']
#
#  conv2d_137 (Conv2D)            (None, 4, 4, 256)    262400      ['activation_125[0][0]']
#
#  batch_normalization_137 (Batch  (None, 4, 4, 256)   1024        ['conv2d_137[0][0]']
#  Normalization)
#
#  activation_126 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_137[0][0]']
#
#  conv2d_138 (Conv2D)            (None, 4, 4, 256)    590080      ['activation_126[0][0]']
#
#  batch_normalization_138 (Batch  (None, 4, 4, 256)   1024        ['conv2d_138[0][0]']
#  Normalization)
#
#  activation_127 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_138[0][0]']
#
#  conv2d_139 (Conv2D)            (None, 4, 4, 1024)   263168      ['activation_127[0][0]']
#
#  batch_normalization_139 (Batch  (None, 4, 4, 1024)  4096        ['conv2d_139[0][0]']
#  Normalization)
#
#  add_41 (Add)                   (None, 4, 4, 1024)   0           ['activation_125[0][0]',
#                                                                   'batch_normalization_139[0][0]']
#
#  activation_128 (Activation)    (None, 4, 4, 1024)   0           ['add_41[0][0]']
#
#  conv2d_140 (Conv2D)            (None, 4, 4, 256)    262400      ['activation_128[0][0]']
#
#  batch_normalization_140 (Batch  (None, 4, 4, 256)   1024        ['conv2d_140[0][0]']
#  Normalization)
#
#  activation_129 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_140[0][0]']
#
#  conv2d_141 (Conv2D)            (None, 4, 4, 256)    590080      ['activation_129[0][0]']
#
#  batch_normalization_141 (Batch  (None, 4, 4, 256)   1024        ['conv2d_141[0][0]']
#  Normalization)
#
#  activation_130 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_141[0][0]']
#
#  conv2d_142 (Conv2D)            (None, 4, 4, 1024)   263168      ['activation_130[0][0]']
#
#  batch_normalization_142 (Batch  (None, 4, 4, 1024)  4096        ['conv2d_142[0][0]']
#  Normalization)
#
#  add_42 (Add)                   (None, 4, 4, 1024)   0           ['activation_128[0][0]',
#                                                                   'batch_normalization_142[0][0]']
#
#  activation_131 (Activation)    (None, 4, 4, 1024)   0           ['add_42[0][0]']
#
#  conv2d_143 (Conv2D)            (None, 4, 4, 256)    262400      ['activation_131[0][0]']
#
#  batch_normalization_143 (Batch  (None, 4, 4, 256)   1024        ['conv2d_143[0][0]']
#  Normalization)
#
#  activation_132 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_143[0][0]']
#
#  conv2d_144 (Conv2D)            (None, 4, 4, 256)    590080      ['activation_132[0][0]']
#
#  batch_normalization_144 (Batch  (None, 4, 4, 256)   1024        ['conv2d_144[0][0]']
#  Normalization)
#
#  activation_133 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_144[0][0]']
#
#  conv2d_145 (Conv2D)            (None, 4, 4, 1024)   263168      ['activation_133[0][0]']
#
#  batch_normalization_145 (Batch  (None, 4, 4, 1024)  4096        ['conv2d_145[0][0]']
#  Normalization)
#
#  add_43 (Add)                   (None, 4, 4, 1024)   0           ['activation_131[0][0]',
#                                                                   'batch_normalization_145[0][0]']
#
#  activation_134 (Activation)    (None, 4, 4, 1024)   0           ['add_43[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 4, 4, 256)    262400      ['activation_134[0][0]']
#
#  batch_normalization_146 (Batch  (None, 4, 4, 256)   1024        ['conv2d_146[0][0]']
#  Normalization)
#
#  activation_135 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_146[0][0]']
#
#  conv2d_147 (Conv2D)            (None, 4, 4, 256)    590080      ['activation_135[0][0]']
#
#  batch_normalization_147 (Batch  (None, 4, 4, 256)   1024        ['conv2d_147[0][0]']
#  Normalization)
#  activation_136 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_147[0][0]']
#
#  conv2d_148 (Conv2D)            (None, 4, 4, 1024)   263168      ['activation_136[0][0]']
#
#  batch_normalization_148 (Batch  (None, 4, 4, 1024)  4096        ['conv2d_148[0][0]']
#  Normalization)
#
#  add_44 (Add)                   (None, 4, 4, 1024)   0           ['activation_134[0][0]',
#                                                                   'batch_normalization_148[0][0]']
#
#  activation_137 (Activation)    (None, 4, 4, 1024)   0           ['add_44[0][0]']
#
#  conv2d_149 (Conv2D)            (None, 2, 2, 512)    524800      ['activation_137[0][0]']
#
#  batch_normalization_149 (Batch  (None, 2, 2, 512)   2048        ['conv2d_149[0][0]']
#  Normalization)
#
#  activation_138 (Activation)    (None, 2, 2, 512)    0           ['batch_normalization_149[0][0]']
#
#  conv2d_150 (Conv2D)            (None, 2, 2, 512)    2359808     ['activation_138[0][0]']
#
#  batch_normalization_150 (Batch  (None, 2, 2, 512)   2048        ['conv2d_150[0][0]']
#  Normalization)
#
#  activation_139 (Activation)    (None, 2, 2, 512)    0           ['batch_normalization_150[0][0]']
#
#  conv2d_151 (Conv2D)            (None, 2, 2, 2048)   1050624     ['activation_139[0][0]']
#
#  conv2d_152 (Conv2D)            (None, 2, 2, 2048)   2099200     ['activation_137[0][0]']
#
#  batch_normalization_151 (Batch  (None, 2, 2, 2048)  8192        ['conv2d_151[0][0]']
#  Normalization)
#
#  batch_normalization_152 (Batch  (None, 2, 2, 2048)  8192        ['conv2d_152[0][0]']
#  Normalization)
#
#  add_45 (Add)                   (None, 2, 2, 2048)   0           ['batch_normalization_151[0][0]',
#                                                                   'batch_normalization_152[0][0]']
#
#  activation_140 (Activation)    (None, 2, 2, 2048)   0           ['add_45[0][0]']
#
#  conv2d_153 (Conv2D)            (None, 2, 2, 512)    1049088     ['activation_140[0][0]']
#
#  batch_normalization_153 (Batch  (None, 2, 2, 512)   2048        ['conv2d_153[0][0]']
#  Normalization)
#
#  activation_141 (Activation)    (None, 2, 2, 512)    0           ['batch_normalization_153[0][0]']
#
#  conv2d_154 (Conv2D)            (None, 2, 2, 512)    2359808     ['activation_141[0][0]']
#
#  batch_normalization_154 (Batch  (None, 2, 2, 512)   2048        ['conv2d_154[0][0]']
#  Normalization)
#
#  activation_142 (Activation)    (None, 2, 2, 512)    0           ['batch_normalization_154[0][0]']
#
#  conv2d_155 (Conv2D)            (None, 2, 2, 2048)   1050624     ['activation_142[0][0]']
#
#  batch_normalization_155 (Batch  (None, 2, 2, 2048)  8192        ['conv2d_155[0][0]']
#  Normalization)
#
#  add_46 (Add)                   (None, 2, 2, 2048)   0           ['activation_140[0][0]',
#                                                                   'batch_normalization_155[0][0]']
#
#  activation_143 (Activation)    (None, 2, 2, 2048)   0           ['add_46[0][0]']
#
#  conv2d_156 (Conv2D)            (None, 2, 2, 512)    1049088     ['activation_143[0][0]']
#
#  batch_normalization_156 (Batch  (None, 2, 2, 512)   2048        ['conv2d_156[0][0]']
#  Normalization)
#
#  activation_144 (Activation)    (None, 2, 2, 512)    0           ['batch_normalization_156[0][0]']
#
#  conv2d_157 (Conv2D)            (None, 2, 2, 512)    2359808     ['activation_144[0][0]']
#
#  batch_normalization_157 (Batch  (None, 2, 2, 512)   2048        ['conv2d_157[0][0]']
#  Normalization)
#
#  activation_145 (Activation)    (None, 2, 2, 512)    0           ['batch_normalization_157[0][0]']
#
#  conv2d_158 (Conv2D)            (None, 2, 2, 2048)   1050624     ['activation_145[0][0]']
#
#  batch_normalization_158 (Batch  (None, 2, 2, 2048)  8192        ['conv2d_158[0][0]']
#  Normalization)
#
#  add_47 (Add)                   (None, 2, 2, 2048)   0           ['activation_143[0][0]',
#                                                                   'batch_normalization_158[0][0]']
#
#  activation_146 (Activation)    (None, 2, 2, 2048)   0           ['add_47[0][0]']
#
#  avg_pool (AveragePooling2D)    (None, 1, 1, 2048)   0           ['activation_146[0][0]']
#
#  flatten_2 (Flatten)            (None, 2048)         0           ['avg_pool[0][0]']
#
#  dense_2 (Dense)                (None, 10)           20490       ['flatten_2[0][0]']
#
# ==================================================================================================
# Total params: 23,608,202
# Trainable params: 23,555,082
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# please increase the epoch for higher accuracy (epochs=100)
history = model.fit(train_dataset, validation_data=test_dataset, epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# 675/675 [==============================] - 57s 79ms/step - loss: 1.4958 - accuracy: 0.5362 - val_loss: 1.3669 - val_accuracy: 0.5233
# Epoch 2/5
# 675/675 [==============================] - 53s 79ms/step - loss: 1.0732 - accuracy: 0.6543 - val_loss: 1.1641 - val_accuracy: 0.6131
# Epoch 3/5
# 675/675 [==============================] - 54s 81ms/step - loss: 0.9143 - accuracy: 0.7023 - val_loss: 1.0994 - val_accuracy: 0.6063
# Epoch 4/5
# 675/675 [==============================] - 55s 81ms/step - loss: 1.0619 - accuracy: 0.6754 - val_loss: 0.8076 - val_accuracy: 0.7135
# Epoch 5/5
# 675/675 [==============================] - 55s 81ms/step - loss: 0.8273 - accuracy: 0.7275 - val_loss: 0.9376 - val_accuracy: 0.6859

# %%
model.save(r'model/model_05_epoch.h5')

# %% [markdown]
# # Load model

# %%
from tensorflow.keras.models import load_model
model = load_model(r"model/model_05_epoch.h5")

# %% [markdown]
# # analyzing results and visualization

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16.53, 11.69))
ax1.plot(history.history['accuracy'])
ax1.plot(history.history['val_accuracy'])
ax1.set_xlabel('epoch')
ax1.set_ylabel('accuracy')
ax1.set_title('Accuracy over epoch')
ax1.legend(['Train', 'Test'], loc='upper left')

ax2.plot(history.history['loss'])
ax2.plot(history.history['val_loss'])
ax2.set_xlabel('epoch')
ax2.set_ylabel('loss')
ax2.set_title('Loss over epoch')
ax2.legend(['Train', 'Test'], loc="upper right")

# %% [markdown]
# # Confusion matrix

# %%
y_pred = []  # store predicted labels
y_true = []  # store true labels

# iterate over the dataset
for i, (image_batch, label_batch) in enumerate(test_dataset):   # use dataset.unbatch() with repeat
    # append true labels
    y_true.append(label_batch)
    # compute predictions
    preds = model.predict(image_batch)
    # append predicted labels
    y_pred.append(np.argmax(preds, axis =  1))
    if i==300:
        break

# convert the true and predicted labels into tensors
correct_labels = tf.concat([item for item in y_true], axis = 0)
correct_labels = np.argmax(correct_labels, axis=1)
predicted_labels = tf.concat([item for item in y_pred], axis = 0)
# Out:
# 1/1 [==============================] - 1s 788ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 1s 858ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step

# %%
cm = confusion_matrix(correct_labels, predicted_labels)
cm
# Out:
# array([[842,  10,  55,  11,   3,  22,  62,   0,  29,  29],
#        [  0, 846,  12,   0,   0,   8,   0,   1,   1, 200],
#        [ 31,  28, 567,  35,  15,  10, 292,  50,  19,  22],
#        [ 72,  14,  25, 493,  48,  21, 100,  26, 104,   4],
#        [ 52,   0,   3,  41, 748,   0,  14,  21,  11,   0],
#        [ 30, 123,  32,   8,   0, 307,  51,   2,  59,  82],
#        [228,   9,  62,  27,  15,  15, 497,   8,  25,   5],
#        [  9,   1,  64,  58,  65,   0, 135, 718,  15,   2],
#        [ 58,  40,  36, 135,  12,  43,  11,   5, 541,  16],
#        [ 18,  39,  54,   2,   2,   7,   1,   4,   7, 944]], dtype=int64)

# %%
def plot_confusion_matrix(cm, classes,
                        normalize=False,
                        title='Confusion matrix',
                        figsize=(10, 10),
                        cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=figsize)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar(shrink = 0.7)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
plot_confusion_matrix(cm, train_dataset.class_indices, cmap='Reds')
# Out:
# Confusion matrix, without normalization
# [[842  10  55  11   3  22  62   0  29  29]
#  [  0 846  12   0   0   8   0   1   1 200]
#  [ 31  28 567  35  15  10 292  50  19  22]
#  [ 72  14  25 493  48  21 100  26 104   4]
#  [ 52   0   3  41 748   0  14  21  11   0]
#  [ 30 123  32   8   0 307  51   2  59  82]
#  [228   9  62  27  15  15 497   8  25   5]
#  [  9   1  64  58  65   0 135 718  15   2]
#  [ 58  40  36 135  12  43  11   5 541  16]
#  [ 18  39  54   2   2   7   1   4   7 944]]

# %% [markdown]
# # Thank you
